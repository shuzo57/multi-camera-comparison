# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
fps = 250

# %%
for num in range(10):
    trajectory_path = f"fixed_trajectories/hirasaki_{num}_trajectories.csv"
    
    df = pd.read_csv(trajectory_path, index_col=0)
    keypoints_columns = [col.replace("_x", "") for col in df.columns if col.endswith("_x") and "*" not in col]

    null_rows = df[[col + "_x" for col in keypoints_columns]].isnull().sum(axis=1).values

    plt.figure(figsize=(10, 5))
    plt.plot(np.arange(len(null_rows)) / fps, null_rows)
    plt.xlabel("Frame")
    plt.ylabel("Number of missing keypoints")
    plt.title(f"Number of missing keypoints in hirasaki_{num} over time")
    plt.show()
